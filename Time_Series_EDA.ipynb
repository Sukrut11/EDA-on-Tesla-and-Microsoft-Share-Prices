# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukrut11/EDA-on-Tesla-and-Microsoft-Share-Prices/blob/main/Time_Series_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade pandas-datareader

# %%
import pandas_datareader as pdr # We are going to read the data with this specific library
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_tesla=pdr.get_data_yahoo('TSLA')

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999
# 2017-03-06  50.340000  49.501999  49.582001  50.242001  16777500.0  50.242001

# %%
df_tesla.tail()
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2022-02-18  886.869995  837.609985  ...  22710500.0  856.979980
# 2022-02-22  856.729980  801.099976  ...  27762700.0  821.530029
# 2022-02-23  835.299988  760.559998  ...  31752300.0  764.039978
# 2022-02-24  802.479980  700.000000  ...  45107400.0  800.770020
# 2022-02-25  819.500000  782.400024  ...  25309500.0  809.869995
#
# [5 rows x 6 columns]

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize = (12, 4))
df_tesla.plot()
plt.show()

# %%
plt.figure(figsize = (12, 4))
df_tesla["High"].plot()
plt.show()

# %%
# x limit and y limit
plt.figure(figsize = (12, 4))
df_tesla["High"].plot(xlim = ["2020-01-01", "2021-09-29"])
plt.show()

# %%
# x limit and y limit
plt.figure(figsize = (12, 4))
df_tesla["High"].plot(xlim = ["2020-01-01", "2021-09-29"], ylim = [0, 1000])
plt.show()

# %%
# x limit and y limit
plt.figure(figsize = (12, 4))
df_tesla["High"].plot(xlim = ["2020-01-01", "2021-09-29"], ylim = [0, 1000], color = "red", linestyle = "-.", linewidth = 2.5)
plt.show()

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-02-28', '2017-03-01', '2017-03-02', '2017-03-03',
#                '2017-03-06', '2017-03-07', '2017-03-08', '2017-03-09',
#                '2017-03-10', '2017-03-13',
#                ...
#                '2022-02-11', '2022-02-14', '2022-02-15', '2022-02-16',
#                '2022-02-17', '2022-02-18', '2022-02-22', '2022-02-23',
#                '2022-02-24', '2022-02-25'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
index = df_tesla.loc["2017-02-27" : "2018-03-10"].index
share_open = df_tesla.loc["2017-02-27" : "2018-03-10"]["Open"]

# %%
index
# Out:
# DatetimeIndex(['2017-02-28', '2017-03-01', '2017-03-02', '2017-03-03',
#                '2017-03-06', '2017-03-07', '2017-03-08', '2017-03-09',
#                '2017-03-10', '2017-03-13',
#                ...
#                '2018-02-26', '2018-02-27', '2018-02-28', '2018-03-01',
#                '2018-03-02', '2018-03-05', '2018-03-06', '2018-03-07',
#                '2018-03-08', '2018-03-09'],
#               dtype='datetime64[ns]', name='Date', length=260, freq=None)

# %%
share_open
# Out:
# Date
# 2017-02-28    48.838001
# 2017-03-01    50.835999
# 2017-03-02    49.942001
# 2017-03-03    50.147999
# 2017-03-06    49.582001
#                 ...
# 2018-03-05    66.477997
# 2018-03-06    66.750000
# 2018-03-07    65.087997
# 2018-03-08    66.571999
# 2018-03-09    64.820000
# Name: Open, Length: 260, dtype: float64

# %%
fig, axs = plt.subplots()
plt.tight_layout() # In order to remove the overlapping of xlabels
fig.autofmt_xdate() # In order to remove the overlapping of xlabels
axs.plot(index, share_open)

# %%
# Date time index

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2017-02-28 to 2022-02-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1259 non-null   float64
#  1   Low        1259 non-null   float64
#  2   Open       1259 non-null   float64
#  3   Close      1259 non-null   float64
#  4   Volume     1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
# dtypes: float64(6)
# memory usage: 101.1 KB

# %%
df_tesla = df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   High       1259 non-null   float64
#  2   Low        1259 non-null   float64
#  3   Open       1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Volume     1259 non-null   float64
#  6   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
pd.to_datetime(df_tesla["Date"])
# Out:
# 0      2017-02-28
# 1      2017-03-01
# 2      2017-03-02
# 3      2017-03-03
# 4      2017-03-06
#           ...
# 1254   2022-02-18
# 1255   2022-02-22
# 1256   2022-02-23
# 1257   2022-02-24
# 1258   2022-02-25
# Name: Date, Length: 1259, dtype: datetime64[ns]

# %%
# To set the index after resetting
df_tesla = df_tesla.set_index("Date", drop = True)

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999
# 2017-03-06  50.340000  49.501999  49.582001  50.242001  16777500.0  50.242001

# %%
# Date Time
datetime(2021,9,29)
# Out:
# datetime.datetime(2021, 9, 29, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 2, 27, 17, 6, 26, 572784)

# %% [markdown]
# ####Experimenting with datetime

# %%
def add_num(num1, num2):
  return num1 + num2

# %%
start_time = datetime.now()
num1 = 10
num2 = 10
for i in range(1, 10):
  add_num(num1, num2)
end_time = datetime.now()
print(end_time - start_time)
# Out:
# 0:00:00.000225

# %% [markdown]
# ####Continuing the project

# %%
date = datetime(2021,9,29)

# %%
date
# Out:
# datetime.datetime(2021, 9, 29, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 9, 29)

# %%
date.day
# Out:
# 29

# %%
date.weekday()
# Out:
# 2

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 9

# %% [markdown]
# #### Time Resampling

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999
# 2017-03-06  50.340000  49.501999  49.582001  50.242001  16777500.0  50.242001

# %%
# Time Resampling
df_tesla.resample(rule = "A").min()
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2017-12-31   49.299999   48.556000  ...  14597000.0   48.737999
# 2018-12-31   52.066002   48.917999  ...  15403500.0   50.112000
# 2019-12-31   37.335999   35.397999  ...  12328000.0   35.793999
# 2020-12-31   80.972000   70.101997  ...  17357700.0   72.244003
# 2021-12-31  566.210022  539.489990  ...   9800600.0  563.000000
# 2022-12-31  802.479980  700.000000  ...  16909700.0  764.039978
#
# [6 rows x 6 columns]

# %%
##Rule A == year end frequency
df_tesla.resample(rule = "A").max()["Open"].plot()

# %% [markdown]
# Link for understanding different rules in resample
#
# https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78

# %%
# Quarterly start frequency
df_tesla.resample(rule = "QS").max()["High"].plot()

# %%
# Business End Frequency
df_tesla.resample(rule = "BA").max()
# Out:
#                    High          Low  ...       Volume    Adj Close
# Date                                  ...
# 2017-12-29    77.921997    75.870003  ...   98957000.0    77.000000
# 2018-12-31    77.491997    73.424004  ...  168248500.0    75.914001
# 2019-12-31    87.061996    85.269997  ...  150030500.0    86.188004
# 2020-12-31   718.719971   691.119995  ...  304694000.0   705.669983
# 2021-12-31  1243.489990  1217.000000  ...   89396500.0  1229.910034
# 2022-12-30  1208.000000  1136.040039  ...   50521900.0  1199.780029
#
# [6 rows x 6 columns]

# %%
df_tesla.resample(rule = "BQS").max()
# Out:
#                    High          Low  ...       Volume    Adj Close
# Date                                  ...
# 2017-01-02    56.400002    55.442001  ...   39938000.0    55.660000
# 2017-04-03    77.398003    75.870003  ...   86307000.0    76.690002
# 2017-07-03    77.921997    75.536003  ...   96622500.0    77.000000
# 2017-10-02    72.599998    70.825996  ...   98957000.0    71.930000
# 2018-01-01    72.099998    70.472000  ...  105007000.0    71.484001
# 2018-04-02    74.746002    70.900002  ...  111737000.0    74.166000
# 2018-07-02    77.491997    73.424004  ...  168248500.0    75.914001
# 2018-10-01    75.898003    73.349998  ...  137127500.0    75.358002
# 2019-01-01    70.400002    68.830002  ...  120754000.0    69.461998
# 2019-04-01    59.234001    57.433998  ...  132735500.0    58.362000
# 2019-07-01    53.214001    51.632000  ...  112091500.0    52.976002
# 2019-10-01    87.061996    85.269997  ...  150030500.0    86.188004
# ...

# %% [markdown]
# ####Plotting

# %%
df_tesla["Open"].resample(rule = 'A').mean().plot(kind = "bar")

# %%
df_tesla["Open"].resample(rule = 'M').mean().plot(kind = "bar", figsize=(15,6))

# %%
df_tesla["High"].rolling(11).max().head(20)
# Out:
# Date
# 2017-02-28          NaN
# 2017-03-01          NaN
# 2017-03-02          NaN
# 2017-03-03          NaN
# 2017-03-06          NaN
# 2017-03-07          NaN
# 2017-03-08          NaN
# 2017-03-09          NaN
# 2017-03-10          NaN
# 2017-03-13          NaN
# 2017-03-14    51.624001
# 2017-03-15    52.200001
# 2017-03-16    53.150002
# 2017-03-17    53.150002
# 2017-03-20    53.150002
# 2017-03-21    53.150002
# 2017-03-22    53.150002
# 2017-03-23    53.150002
# 2017-03-24    53.150002
# 2017-03-27    54.113998
# Name: High, dtype: float64

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999
# 2017-03-06  50.340000  49.501999  49.582001  50.242001  16777500.0  50.242001

# %%
df_tesla["Open:30 days rolling"] = df_tesla["Open"].rolling(30).mean()

# %%
df_tesla.head(30)
# Out:
#                  High        Low  ...  Adj Close  Open:30 days rolling
# Date                              ...
# 2017-02-28  50.200001  48.779999  ...  49.998001                   NaN
# 2017-03-01  50.970001  49.821999  ...  50.004002                   NaN
# 2017-03-02  50.655998  49.653999  ...  50.096001                   NaN
# 2017-03-03  50.380001  49.799999  ...  50.313999                   NaN
# 2017-03-06  50.340000  49.501999  ...  50.242001                   NaN
# 2017-03-07  50.778000  49.664001  ...  49.717999                   NaN
# 2017-03-08  50.014000  49.063999  ...  49.374001                   NaN
# 2017-03-09  49.731998  48.599998  ...  48.980000                   NaN
# 2017-03-10  49.299999  48.599998  ...  48.737999                   NaN
# 2017-03-13  49.369999  48.556000  ...  49.234001                   NaN
# 2017-03-14  51.624001  49.203999  ...  51.599998                   NaN
# 2017-03-15  52.200001  50.854000  ...  51.146000                   NaN
# ...

# %%
df_tesla[["Open", "Open:30 days rolling"]].plot(figsize=(12, 5));

# %% [markdown]
# Assignment
#
# 1. Read the Microsoft Data using Pandas Data reader
#
# 2. Get the maximum price of the share from 2017 to 2022
#
# 3. Which is the date of the highest price of the stock?
#
# 4. Which is the date of the lowest price of the stock?

# %%
df_mr = pdr.get_data_yahoo("MSFT")

# %%
df_mr.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  64.199997  63.759998  64.080002  63.980000  23239800.0  59.724354
# 2017-03-01  64.989998  64.019997  64.129997  64.940002  26937500.0  60.620491
# 2017-03-02  64.750000  63.880001  64.690002  64.010002  24539600.0  59.752365
# 2017-03-03  64.279999  63.619999  63.990002  64.250000  18135900.0  59.976391
# 2017-03-06  64.559998  63.810001  63.970001  64.269997  18750300.0  59.995068

# %%
df_mr.tail()
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2022-02-18  293.859985  286.309998  ...  34223200.0  287.929993
# 2022-02-22  291.540009  284.500000  ...  41736100.0  287.720001
# 2022-02-23  291.700012  280.100006  ...  37811200.0  280.269989
# 2022-02-24  295.160004  271.519989  ...  56989700.0  294.589996
# 2022-02-25  297.630005  291.649994  ...  32528000.0  297.309998
#
# [5 rows x 6 columns]

# %%
# xlim
df_mr["High"].plot(figsize = (12, 4))

# %%
df_mr["High"].plot(xlim = ["2020-09-29", "2021-09-29"], figsize = (12, 4))

# %%
# ylim
df_mr["High"].plot(xlim = ["2018-09-29", "2021-09-29"], ylim = [0, 350], figsize = (12, 4))

# %%
# Coloring
df_mr["High"].plot(xlim = ["2018-09-29", "2021-09-29"], ylim = [0, 350], figsize = (12, 4), color = "purple", linestyle = "--")

# %%
df_mr.index
# Out:
# DatetimeIndex(['2017-02-28', '2017-03-01', '2017-03-02', '2017-03-03',
#                '2017-03-06', '2017-03-07', '2017-03-08', '2017-03-09',
#                '2017-03-10', '2017-03-13',
#                ...
#                '2022-02-11', '2022-02-14', '2022-02-15', '2022-02-16',
#                '2022-02-17', '2022-02-18', '2022-02-22', '2022-02-23',
#                '2022-02-24', '2022-02-25'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
index = df_mr.loc["2018-09-29": "2021-09-29"].index
share_open = df_mr.loc["2018-09-29": "2021-09-29"]["Open"]

# %%
share_open
# Out:
# Date
# 2018-10-01    114.750000
# 2018-10-02    115.300003
# 2018-10-03    115.419998
# 2018-10-04    114.610001
# 2018-10-05    112.629997
#                  ...
# 2021-09-23    298.850006
# 2021-09-24    298.230011
# 2021-09-27    296.140015
# 2021-09-28    289.799988
# 2021-09-29    285.100006
# Name: Open, Length: 755, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04',
#                '2018-10-05', '2018-10-08', '2018-10-09', '2018-10-10',
#                '2018-10-11', '2018-10-12',
#                ...
#                '2021-09-16', '2021-09-17', '2021-09-20', '2021-09-21',
#                '2021-09-22', '2021-09-23', '2021-09-24', '2021-09-27',
#                '2021-09-28', '2021-09-29'],
#               dtype='datetime64[ns]', name='Date', length=755, freq=None)

# %%
figure, axs = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axs.plot(index, share_open)
plt.show()

# %%
## Datetime Index
df_mr = df_mr.reset_index()

# %%
df_mr
# Out:
#            Date        High         Low  ...       Close      Volume   Adj Close
# 0    2017-02-28   64.199997   63.759998  ...   63.980000  23239800.0   59.724354
# 1    2017-03-01   64.989998   64.019997  ...   64.940002  26937500.0   60.620491
# 2    2017-03-02   64.750000   63.880001  ...   64.010002  24539600.0   59.752365
# 3    2017-03-03   64.279999   63.619999  ...   64.250000  18135900.0   59.976391
# 4    2017-03-06   64.559998   63.810001  ...   64.269997  18750300.0   59.995068
# ...         ...         ...         ...  ...         ...         ...         ...
# 1254 2022-02-18  293.859985  286.309998  ...  287.929993  34223200.0  287.929993
# 1255 2022-02-22  291.540009  284.500000  ...  287.720001  41736100.0  287.720001
# 1256 2022-02-23  291.700012  280.100006  ...  280.269989  37811200.0  280.269989
# 1257 2022-02-24  295.160004  271.519989  ...  294.589996  56989700.0  294.589996
# 1258 2022-02-25  297.630005  291.649994  ...  297.309998  32528000.0  297.309998
#
# ...

# %%
df_mr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   High       1259 non-null   float64
#  2   Low        1259 non-null   float64
#  3   Open       1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Volume     1259 non-null   float64
#  6   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
df_mr = df_mr.set_index("Date", drop = True)

# %%
df_mr.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  64.199997  63.759998  64.080002  63.980000  23239800.0  59.724354
# 2017-03-01  64.989998  64.019997  64.129997  64.940002  26937500.0  60.620491
# 2017-03-02  64.750000  63.880001  64.690002  64.010002  24539600.0  59.752365
# 2017-03-03  64.279999  63.619999  63.990002  64.250000  18135900.0  59.976391
# 2017-03-06  64.559998  63.810001  63.970001  64.269997  18750300.0  59.995068

# %%
## Time Resampling
df_mr.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  64.199997  63.759998  64.080002  63.980000  23239800.0  59.724354
# 2017-03-01  64.989998  64.019997  64.129997  64.940002  26937500.0  60.620491
# 2017-03-02  64.750000  63.880001  64.690002  64.010002  24539600.0  59.752365
# 2017-03-03  64.279999  63.619999  63.990002  64.250000  18135900.0  59.976391
# 2017-03-06  64.559998  63.810001  63.970001  64.269997  18750300.0  59.995068

# %%
df_mr.resample(rule = "A").min()
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2017-12-31   64.199997   63.619999  ...   7425600.0   59.724354
# 2018-12-31   86.309998   83.830002  ...  13677200.0   80.638580
# 2019-12-31  100.190002   97.199997  ...   8989200.0   93.990868
# 2020-12-31  140.570007  132.520004  ...  10550600.0  132.974564
# 2021-12-31  214.509995  211.940002  ...  13900200.0  210.051315
# 2022-12-31  291.540009  271.519989  ...  27379500.0  280.269989
#
# [6 rows x 6 columns]

# %%
df_mr.resample(rule = "A").max()
# Out:
#                   High         Low  ...       Volume   Adj Close
# Date                                ...
# 2017-12-31   87.500000   86.230003  ...   71066700.0   82.383942
# 2018-12-31  116.180000  114.930000  ...  111242100.0  111.083595
# 2019-12-31  159.550003  158.220001  ...   55636400.0  155.664291
# 2020-12-31  232.860001  227.350006  ...   97012700.0  228.651733
# 2021-12-31  349.670013  342.200012  ...   69870600.0  342.402008
# 2022-12-31  338.000000  329.779999  ...   90428900.0  334.059265
#
# [6 rows x 6 columns]

# %%
##year end frequency
df_mr.resample(rule = "A").max()["Open"].plot()

# %%
##quaterly start frequency
df_mr.resample(rule = "QS").max()["High"].plot()

# %%
## Business End Frequency
df_mr.resample(rule = "BA").max()
# Out:
#                   High         Low  ...       Volume   Adj Close
# Date                                ...
# 2017-12-29   87.500000   86.230003  ...   71066700.0   82.383942
# 2018-12-31  116.180000  114.930000  ...  111242100.0  111.083595
# 2019-12-31  159.550003  158.220001  ...   55636400.0  155.664291
# 2020-12-31  232.860001  227.350006  ...   97012700.0  228.651733
# 2021-12-31  349.670013  342.200012  ...   69870600.0  342.402008
# 2022-12-30  338.000000  329.779999  ...   90428900.0  334.059265
#
# [6 rows x 6 columns]

# %%
df_mr.resample(rule = "BQS").max()
# Out:
#                   High         Low  ...       Volume   Adj Close
# Date                                ...
# 2017-01-02   66.190002   65.449997  ...   49219700.0   61.479301
# 2017-04-03   72.889999   72.269997  ...   49187400.0   68.084351
# 2017-07-03   75.970001   75.040001  ...   46717100.0   71.203094
# 2017-10-02   87.500000   86.230003  ...   71066700.0   82.383942
# 2018-01-01   97.239998   96.040001  ...   67998600.0   92.225029
# 2018-04-02  102.690002  101.900002  ...   65738600.0   98.099754
# 2018-07-02  115.290001  114.199997  ...   71229700.0  110.180389
# 2018-10-01  116.180000  114.930000  ...  111242100.0  111.083595
# 2019-01-01  120.820000  117.089996  ...   55636400.0  116.507591
# 2019-04-01  138.399994  137.000000  ...   38033900.0  134.019577
# 2019-07-01  142.369995  140.300003  ...   48992400.0  137.676727
# 2019-10-01  159.550003  158.220001  ...   53477500.0  155.664291
# 2020-01-01  190.699997  186.470001  ...   97012700.0  184.787704
# ...

# %%
## Plotting
df_mr["Open"].resample(rule = "A").mean().plot(kind = "bar")

# %%
df_mr["Open"].resample(rule = "M").max().plot(kind = "bar", figsize = (15, 6))

# %%
df_mr["High"].rolling(11).max().head(20)
# Out:
# Date
# 2017-02-28          NaN
# 2017-03-01          NaN
# 2017-03-02          NaN
# 2017-03-03          NaN
# 2017-03-06          NaN
# 2017-03-07          NaN
# 2017-03-08          NaN
# 2017-03-09          NaN
# 2017-03-10          NaN
# 2017-03-13          NaN
# 2017-03-14    65.260002
# 2017-03-15    65.260002
# 2017-03-16    65.260002
# 2017-03-17    65.260002
# 2017-03-20    65.260002
# 2017-03-21    65.500000
# 2017-03-22    65.500000
# 2017-03-23    65.500000
# 2017-03-24    65.500000
# 2017-03-27    65.500000
# Name: High, dtype: float64

# %%
df_mr.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-28  64.199997  63.759998  64.080002  63.980000  23239800.0  59.724354
# 2017-03-01  64.989998  64.019997  64.129997  64.940002  26937500.0  60.620491
# 2017-03-02  64.750000  63.880001  64.690002  64.010002  24539600.0  59.752365
# 2017-03-03  64.279999  63.619999  63.990002  64.250000  18135900.0  59.976391
# 2017-03-06  64.559998  63.810001  63.970001  64.269997  18750300.0  59.995068

# %%
df_mr["Open: 30 days rolling"] = df_mr["Open"].rolling(30).mean()

# %%
df_mr.head(31)
# Out:
#                  High        Low  ...  Adj Close  Open: 30 days rolling
# Date                              ...
# 2017-02-28  64.199997  63.759998  ...  59.724354                    NaN
# 2017-03-01  64.989998  64.019997  ...  60.620491                    NaN
# 2017-03-02  64.750000  63.880001  ...  59.752365                    NaN
# 2017-03-03  64.279999  63.619999  ...  59.976391                    NaN
# 2017-03-06  64.559998  63.810001  ...  59.995068                    NaN
# 2017-03-07  64.779999  64.190002  ...  60.116425                    NaN
# 2017-03-08  65.080002  64.250000  ...  60.667183                    NaN
# 2017-03-09  65.199997  64.480003  ...  60.424465                    NaN
# 2017-03-10  65.260002  64.750000  ...  60.611156                    NaN
# 2017-03-13  65.190002  64.570000  ...  60.405796                    NaN
# 2017-03-14  64.550003  64.150002  ...  60.125759                    NaN
# ...

# %%
df_mr[["Open", "Open: 30 days rolling"]].plot(figsize = (12, 5))
